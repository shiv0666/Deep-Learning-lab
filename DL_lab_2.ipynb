# %% [markdown]
# Shivansh Lohani
# 23070521141

# %% [markdown]
# ## Linear Regression Analysis

# %% [markdown]
# ### Manual Linear Regression Calculation

# %%
import numpy as np
import matplotlib.pyplot as plt

# Input data
# x = np.array([100, 150, 200, 250, 300])
# y = np.array([20, 25, 30, 35, 40])

# Calculate means
mean_x = np.mean(x)
mean_y = np.mean(y)

# Calculate the slope (b1)
numerator = np.sum((x - mean_x) * (y - mean_y))
denominator = np.sum((x - mean_x)**2)

# Avoid division by zero if all x values are the same
if denominator == 0:
    manual_slope = 0
else:
    manual_slope = numerator / denominator

# Calculate the intercept (b0)
manual_intercept = mean_y - manual_slope * mean_x

print(f"Manual Slope: {manual_slope:.2f}")
print(f"Manual Intercept: {manual_intercept:.2f}")
# Out:
# Manual Slope: 0.10
# Manual Intercept: 10.00

# %%
# Predict y values using the manually calculated slope and intercept
y_pred_manual = manual_slope * x + manual_intercept

# Calculate evaluation metrics manually
manual_mae = np.mean(np.abs(y - y_pred_manual))
manual_mse = np.mean((y - y_pred_manual)**2)
manual_rmse = np.sqrt(manual_mse)

print(f"Manual Mean Absolute Error (MAE): {manual_mae:.2f}")
print(f"Manual Mean Squared Error (MSE): {manual_mse:.2f}")
print(f"Manual Root Mean Squared Error (RMSE): {manual_rmse:.2f}")
# Out:
# Manual Mean Absolute Error (MAE): 0.00
# Manual Mean Squared Error (MSE): 0.00
# Manual Root Mean Squared Error (RMSE): 0.00

# %%
# Plot the original data and the manually calculated regression line
plt.figure(figsize=(8, 6))
plt.scatter(x, y, color='blue', label='Original Data')
plt.plot(x, y_pred_manual, color='green', label='Manual Regression Line')
plt.title('Manual Linear Regression')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.legend()
plt.grid(True)
plt.show()
