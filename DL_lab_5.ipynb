# %%
# Shivansh lohani: 23070521141
# ============================================================
# PRACTICAL: Hyperparameter Tuning and Model Optimization
# ============================================================

import tensorflow as tf
import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam, SGD, RMSprop

# ============================================================
# STEP 1: Load Dataset
# ============================================================

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

# ============================================================
# STEP 2: Function to Build Model
# ============================================================

def build_model(hidden_layers=1,
                neurons=128,
                activation='relu',
                learning_rate=0.001,
                optimizer_name='adam'):

    model = Sequential()

    model.add(Flatten(input_shape=(28,28)))

    for i in range(hidden_layers):
        model.add(Dense(neurons,
                        activation=activation))

    model.add(Dense(10,
                    activation='softmax'))

    if optimizer_name == 'adam':
        optimizer = Adam(learning_rate=learning_rate)

    elif optimizer_name == 'sgd':
        optimizer = SGD(learning_rate=learning_rate)

    elif optimizer_name == 'rmsprop':
        optimizer = RMSprop(learning_rate=learning_rate)

    model.compile(
        optimizer=optimizer,
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# ============================================================
# STEP 3: Hyperparameter Combinations
# ============================================================

learning_rates = [0.1, 0.01, 0.001]

batch_sizes = [32,64]

hidden_layers = [1,2]

activations = ['relu','tanh']

optimizers = ['adam','sgd','rmsprop']

# ============================================================
# STEP 4: Hyperparameter Tuning
# ============================================================

results = []

experiment = 1

for lr in learning_rates:

    for batch in batch_sizes:

        for layer in hidden_layers:

            for act in activations:

                for opt in optimizers:

                    print("="*60)
                    print("Experiment",experiment)
                    print("LR:",lr,
                          "Batch:",batch,
                          "Layers:",layer,
                          "Activation:",act,
                          "Optimizer:",opt)

                    model = build_model(
                        hidden_layers=layer,
                        activation=act,
                        learning_rate=lr,
                        optimizer_name=opt
                    )

                    history = model.fit(
                        x_train,
                        y_train,
                        epochs=5,
                        batch_size=batch,
                        validation_split=0.2,
                        verbose=0
                    )

                    val_accuracy = history.history['val_accuracy'][-1]
                    train_accuracy = history.history['accuracy'][-1]
                    val_loss = history.history['val_loss'][-1]

                    results.append([
                        lr,
                        batch,
                        layer,
                        act,
                        opt,
                        train_accuracy,
                        val_accuracy,
                        val_loss
                    ])

                    experiment += 1

# ============================================================
# STEP 5: Display Results
# ============================================================

columns = [
    "Learning Rate",
    "Batch Size",
    "Hidden Layers",
    "Activation",
    "Optimizer",
    "Training Accuracy",
    "Validation Accuracy",
    "Validation Loss"
]

results_df = pd.DataFrame(results,
                          columns=columns)

print(results_df)

# ============================================================
# STEP 6: Best Hyperparameters
# ============================================================

best = results_df.sort_values(
    by="Validation Accuracy",
    ascending=False
).head(1)

print("\nBest Hyperparameter Combination\n")

print(best)

# ============================================================
# STEP 7: Save Results
# ============================================================

results_df.to_csv(
    "Hyperparameter_Tuning_Results.csv",
    index=False
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ============================================================
# Experiment 1
# LR: 0.1 Batch: 32 Layers: 1 Activation: relu Optimizer: adam
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# ============================================================
# Experiment 2
# LR: 0.1 Batch: 32 Layers: 1 Activation: relu Optimizer: sgd
# ============================================================
# Experiment 3
# LR: 0.1 Batch: 32 Layers: 1 Activation: relu Optimizer: rmsprop
# ============================================================
# Experiment 4
# LR: 0.1 Batch: 32 Layers: 1 Activation: tanh Optimizer: adam
# ============================================================
# Experiment 5
# LR: 0.1 Batch: 32 Layers: 1 Activation: tanh Optimizer: sgd
# ============================================================
# Experiment 6
# LR: 0.1 Batch: 32 Layers: 1 Activation: tanh Optimizer: rmsprop
# ============================================================
# Experiment 7
# LR: 0.1 Batch: 32 Layers: 2 Activation: relu Optimizer: adam
# ============================================================
# Experiment 8
# LR: 0.1 Batch: 32 Layers: 2 Activation: relu Optimizer: sgd
# ============================================================
# Experiment 9
# LR: 0.1 Batch: 32 Layers: 2 Activation: relu Optimizer: rmsprop
# ============================================================
# Experiment 10
# LR: 0.1 Batch: 32 Layers: 2 Activation: tanh Optimizer: adam
# ============================================================
# Experiment 11
# LR: 0.1 Batch: 32 Layers: 2 Activation: tanh Optimizer: sgd
# ============================================================
# Experiment 12
# LR: 0.1 Batch: 32 Layers: 2 Activation: tanh Optimizer: rmsprop
# ============================================================
# Experiment 13
# LR: 0.1 Batch: 64 Layers: 1 Activation: relu Optimizer: adam
# ============================================================
# Experiment 14
# LR: 0.1 Batch: 64 Layers: 1 Activation: relu Optimizer: sgd
# ============================================================
# Experiment 15
# LR: 0.1 Batch: 64 Layers: 1 Activation: relu Optimizer: rmsprop
# ============================================================
# Experiment 16
# LR: 0.1 Batch: 64 Layers: 1 Activation: tanh Optimizer: adam
# ============================================================
# Experiment 17
# LR: 0.1 Batch: 64 Layers: 1 Activation: tanh Optimizer: sgd
# ============================================================
# Experiment 18
# LR: 0.1 Batch: 64 Layers: 1 Activation: tanh Optimizer: rmsprop
# ============================================================
# Experiment 19
# LR: 0.1 Batch: 64 Layers: 2 Activation: relu Optimizer: adam
# ============================================================
# Experiment 20
# LR: 0.1 Batch: 64 Layers: 2 Activation: relu Optimizer: sgd
# ============================================================
# Experiment 21
# LR: 0.1 Batch: 64 Layers: 2 Activation: relu Optimizer: rmsprop
# ============================================================
# Experiment 22
# LR: 0.1 Batch: 64 Layers: 2 Activation: tanh Optimizer: adam
# ============================================================
# Experiment 23
# LR: 0.1 Batch: 64 Layers: 2 Activation: tanh Optimizer: sgd
# ============================================================
# Experiment 24
# LR: 0.1 Batch: 64 Layers: 2 Activation: tanh Optimizer: rmsprop
# ============================================================
# Experiment 25
# LR: 0.01 Batch: 32 Layers: 1 Activation: relu Optimizer: adam
# ============================================================
# Experiment 26
# LR: 0.01 Batch: 32 Layers: 1 Activation: relu Optimizer: sgd
# ============================================================
# Experiment 27
# LR: 0.01 Batch: 32 Layers: 1 Activation: relu Optimizer: rmsprop
# ============================================================
# Experiment 28
# LR: 0.01 Batch: 32 Layers: 1 Activation: tanh Optimizer: adam
# ============================================================
# Experiment 29
# LR: 0.01 Batch: 32 Layers: 1 Activation: tanh Optimizer: sgd
# ============================================================
# Experiment 30
# LR: 0.01 Batch: 32 Layers: 1 Activation: tanh Optimizer: rmsprop
# ============================================================
# Experiment 31
# LR: 0.01 Batch: 32 Layers: 2 Activation: relu Optimizer: adam
# ============================================================
# Experiment 32
# LR: 0.01 Batch: 32 Layers: 2 Activation: relu Optimizer: sgd
# ============================================================
# Experiment 33
# LR: 0.01 Batch: 32 Layers: 2 Activation: relu Optimizer: rmsprop
# ============================================================
# Experiment 34
# LR: 0.01 Batch: 32 Layers: 2 Activation: tanh Optimizer: adam
# ============================================================
# Experiment 35
# LR: 0.01 Batch: 32 Layers: 2 Activation: tanh Optimizer: sgd
# ============================================================
# Experiment 36
# LR: 0.01 Batch: 32 Layers: 2 Activation: tanh Optimizer: rmsprop
# ============================================================
# Experiment 37
# LR: 0.01 Batch: 64 Layers: 1 Activation: relu Optimizer: adam
# ============================================================
# Experiment 38
# LR: 0.01 Batch: 64 Layers: 1 Activation: relu Optimizer: sgd
# ============================================================
# Experiment 39
# LR: 0.01 Batch: 64 Layers: 1 Activation: relu Optimizer: rmsprop
# ============================================================
# Experiment 40
# LR: 0.01 Batch: 64 Layers: 1 Activation: tanh Optimizer: adam
# ============================================================
# Experiment 41
# LR: 0.01 Batch: 64 Layers: 1 Activation: tanh Optimizer: sgd
# ============================================================
# Experiment 42
# LR: 0.01 Batch: 64 Layers: 1 Activation: tanh Optimizer: rmsprop
# ============================================================
# Experiment 43
# LR: 0.01 Batch: 64 Layers: 2 Activation: relu Optimizer: adam
# ============================================================
# Experiment 44
# LR: 0.01 Batch: 64 Layers: 2 Activation: relu Optimizer: sgd
# ============================================================
# Experiment 45
# LR: 0.01 Batch: 64 Layers: 2 Activation: relu Optimizer: rmsprop
# ============================================================
# Experiment 46
# LR: 0.01 Batch: 64 Layers: 2 Activation: tanh Optimizer: adam
# ============================================================
# Experiment 47
# LR: 0.01 Batch: 64 Layers: 2 Activation: tanh Optimizer: sgd
# ============================================================
# Experiment 48
# LR: 0.01 Batch: 64 Layers: 2 Activation: tanh Optimizer: rmsprop
# ============================================================
# Experiment 49
# LR: 0.001 Batch: 32 Layers: 1 Activation: relu Optimizer: adam
# ============================================================
# Experiment 50
# LR: 0.001 Batch: 32 Layers: 1 Activation: relu Optimizer: sgd
# ============================================================
# Experiment 51
# LR: 0.001 Batch: 32 Layers: 1 Activation: relu Optimizer: rmsprop
# ============================================================
# Experiment 52
# LR: 0.001 Batch: 32 Layers: 1 Activation: tanh Optimizer: adam
# ============================================================
# Experiment 53
# LR: 0.001 Batch: 32 Layers: 1 Activation: tanh Optimizer: sgd
# ============================================================
# Experiment 54
# LR: 0.001 Batch: 32 Layers: 1 Activation: tanh Optimizer: rmsprop
# ============================================================
# Experiment 55
# LR: 0.001 Batch: 32 Layers: 2 Activation: relu Optimizer: adam
# ============================================================
# Experiment 56
# LR: 0.001 Batch: 32 Layers: 2 Activation: relu Optimizer: sgd
# ============================================================
# Experiment 57
# LR: 0.001 Batch: 32 Layers: 2 Activation: relu Optimizer: rmsprop
# ============================================================
# Experiment 58
# LR: 0.001 Batch: 32 Layers: 2 Activation: tanh Optimizer: adam
# ============================================================
# Experiment 59
# LR: 0.001 Batch: 32 Layers: 2 Activation: tanh Optimizer: sgd
# ============================================================
# Experiment 60
# LR: 0.001 Batch: 32 Layers: 2 Activation: tanh Optimizer: rmsprop
# ============================================================
# Experiment 61
# LR: 0.001 Batch: 64 Layers: 1 Activation: relu Optimizer: adam
# ============================================================
# Experiment 62
# LR: 0.001 Batch: 64 Layers: 1 Activation: relu Optimizer: sgd
# ============================================================
# Experiment 63
# LR: 0.001 Batch: 64 Layers: 1 Activation: relu Optimizer: rmsprop
# ============================================================
# Experiment 64
# LR: 0.001 Batch: 64 Layers: 1 Activation: tanh Optimizer: adam
# ============================================================
# Experiment 65
# LR: 0.001 Batch: 64 Layers: 1 Activation: tanh Optimizer: sgd
# ============================================================
# Experiment 66
# LR: 0.001 Batch: 64 Layers: 1 Activation: tanh Optimizer: rmsprop
# ============================================================
# Experiment 67
# LR: 0.001 Batch: 64 Layers: 2 Activation: relu Optimizer: adam
# ============================================================
# Experiment 68
# LR: 0.001 Batch: 64 Layers: 2 Activation: relu Optimizer: sgd
# ============================================================
# Experiment 69
# LR: 0.001 Batch: 64 Layers: 2 Activation: relu Optimizer: rmsprop
# ============================================================
# Experiment 70
# LR: 0.001 Batch: 64 Layers: 2 Activation: tanh Optimizer: adam
# ============================================================
# Experiment 71
# LR: 0.001 Batch: 64 Layers: 2 Activation: tanh Optimizer: sgd
# ============================================================
# Experiment 72
# LR: 0.001 Batch: 64 Layers: 2 Activation: tanh Optimizer: rmsprop
#     Learning Rate  Batch Size  Hidden Layers Activation Optimizer  \
# 0           0.100          32              1       relu      adam
# 1           0.100          32              1       relu       sgd
# 2           0.100          32              1       relu   rmsprop
# 3           0.100          32              1       tanh      adam
# 4           0.100          32              1       tanh       sgd
# ..            ...         ...            ...        ...       ...
# 67          0.001          64              2       relu       sgd
# 68          0.001          64              2       relu   rmsprop
# 69          0.001          64              2       tanh      adam
# 70          0.001          64              2       tanh       sgd
# 71          0.001          64              2       tanh   rmsprop
#
#     Training Accuracy  Validation Accuracy  Validation Loss
# 0            0.512479             0.423917         1.612086
# 1            0.977500             0.972667         0.096314
# 2            0.853771             0.870667         0.995986
# 3            0.790646             0.780250         2.003838
# 4            0.971208             0.966417         0.115953
# ..                ...                  ...              ...
# 67           0.806063             0.836750         0.750548
# 68           0.984312             0.968083         0.116672
# 69           0.983208             0.971750         0.091391
# 70           0.847667             0.865667         0.600400
# 71           0.981542             0.971750         0.094972
#
# [72 rows x 8 columns]
#
# Best Hyperparameter Combination
#
#     Learning Rate  Batch Size  Hidden Layers Activation Optimizer  \
# 56          0.001          32              2       relu   rmsprop
#
#     Training Accuracy  Validation Accuracy  Validation Loss
# 56           0.984979             0.975167         0.109202
